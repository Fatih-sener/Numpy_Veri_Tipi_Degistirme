# %%
import numpy as np

# %%
sayilar=np.array([1,2,3,4,5,6])

# %%
sayilar.dtype
# Out:
# dtype('int32')

# %%
sayilar = np.array([1,2,3,4,5.0,6])

# %%
sayilar.dtype
# Out:
# dtype('float64')

# %%
sayilar = sayilar.astype("int8")
sayilar.dtype
# Out:
# dtype('int8')

# %%
sayilar = np.array([1,2,3,4,5,6,7],dtype="int8")
sayilar.dtype
# Out:
# dtype('int8')

# %%
tarih = np.array(["2023-01-01"])
tarih.dtype
# Out:
# dtype('<U10')
